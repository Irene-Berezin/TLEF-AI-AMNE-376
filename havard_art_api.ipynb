# %%
import requests
import os
import csv
import re

# === Configuration ===
API_KEY = '8a3e7b04-96e1-45f3-9666-20c5dbb4dd88'  # replace with your Harvard Art Museums API key
BASE_URL = 'https://api.harvardartmuseums.org/object'
cultures = ["Byzantine", "Greek", "Roman", "Egyptian"]
classifications = [
    "Architecture Elements", "Coins", "Paintings", "Sculpture",
    "Seals", "Vessels", "Weapons and Ammunitions"
]
max_per_combo = 150

# Prepare output CSV
data_csv = 'metadata.csv'
csv_fields = ['id', 'title', 'classification', 'century', 'culture', 'image_path']
with open(data_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(csv_fields)

# Helper: sanitize filesystem names
def sanitize(name):
    return re.sub(r"'[<>:/\\|?*]'", '_', name)

# Summary counters
total_downloaded = 0
breakdown = {}

# Loop through culture-classification combinations
for culture in cultures:
    for cls in classifications:
        # Query and collect up to 2x needed for balancing
        items = []
        page = 1
        while True:
            params = {
                'apikey': API_KEY,
                'q': f'culture:"{culture}" AND classification:"{cls}"',
                'hasimage': 1,
                'size': 100,
                'page': page
            }
            resp = requests.get(BASE_URL, params=params)
            resp.raise_for_status()
            data = resp.json()
            records = data.get('records', [])
            if not records:
                break

            for rec in records:
                if rec.get('primaryimageurl'):
                    items.append(rec)
                if len(items) >= max_per_combo * 2:
                    break
            if len(items) >= max_per_combo * 2:
                break
            if data.get('info', {}).get('next'):
                page += 1
            else:
                break

        # Select items: balance centuries if > max_per_combo
        if len(items) > max_per_combo:
            by_cent = {}
            for rec in items:
                cent = rec.get('century') or 'Unknown'
                by_cent.setdefault(cent, []).append(rec)
            sel = []
            idxs = {cent: 0 for cent in by_cent}
            cents = list(by_cent.keys())
            i = 0
            while len(sel) < max_per_combo and cents:
                cent = cents[i % len(cents)]
                lst = by_cent[cent]
                if idxs[cent] < len(lst):
                    sel.append(lst[idxs[cent]])
                    idxs[cent] += 1
                else:
                    cents.remove(cent)
                i += 1
            if len(sel) < max_per_combo:
                remaining = [r for r in items if r not in sel]
                sel += remaining[:max_per_combo - len(sel)]
        else:
            sel = items

        # Download and save metadata
        count = 0
        for rec in sel:
            img_url = rec.get('primaryimageurl')
            if not img_url:
                continue

            # Download image and infer extension
            try:
                r = requests.get(img_url, timeout=10)
                r.raise_for_status()
                ctype = r.headers.get('Content-Type', '')
                if not ctype.startswith('image/'):
                    print(f"Skipping non-image URL: {img_url}")
                    continue
                ext_map = {'jpeg': '.jpg', 'png': '.png', 'gif': '.gif', 'tiff': '.tif', 'bmp': '.bmp'}
                ext = ext_map.get(ctype.split('/')[-1], '.jpg')
                content = r.content
            except Exception as e:
                print(f"Error downloading {img_url}: {e}")
                continue

            # Build sanitized filename
            fname_root = os.path.basename(img_url).split('?')[0]
            safe_name = sanitize(fname_root) or rec.get('id', 'img')
            safe_name += ext

            # Create folder and save image
            folder = os.path.join('images', sanitize(culture), sanitize(cls))
            os.makedirs(folder, exist_ok=True)
            path = os.path.join(folder, safe_name)
            try:
                with open(path, 'wb') as f:
                    f.write(content)
            except Exception as e:
                print(f"Error saving file {path}: {e}")
                continue

            # Append metadata
            with open(data_csv, 'a', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerow([rec.get('id'), rec.get('title', '').strip(), cls, rec.get('century'), culture, path])
            count += 1

        total_downloaded += count
        breakdown[(culture, cls)] = count

# Print summary
print(f"Total images downloaded: {total_downloaded}")
print("Downloaded per culture-classification:")
for (culture, cls), cnt in breakdown.items():
    print(f" - {culture} / {cls}: {cnt}")
# Out:
# Error saving file images\Byzantine\Architecture Elements\urn-3:HUAM:VRS14176_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Architecture Elements\\urn-3:HUAM:VRS14176_dynmc.jpg'
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN21165_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43355497
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19127_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352722
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19128_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352723
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN14063_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43348078
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12781_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345401
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11856_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343597
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12247_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342981
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11855_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343596
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12019_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342757
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11805_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343553
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11868_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343608
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN15959_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43350875
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11844_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343587
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12018_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342756
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11807_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343555
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11867_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343607
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13052_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345671
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11842_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343585
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12017_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342755
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11824_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343572
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11866_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343606
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13109_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345725
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11822_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343570
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11865_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343605
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13123_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345739
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11857_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343598
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN15960_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43350876
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11838_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343581
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12014_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342752
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11819_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343567
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11863_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343603
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13124_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345740
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12028_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342766
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN15941_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43350858
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11836_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343579
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12012_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342750
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11817_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343565
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13128_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345744
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12103_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342837
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19057_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352652
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12766_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345386
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12008_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342746
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11832_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343575
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12002_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342740
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13129_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345745
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12082_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342816
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19058_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352653
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11841_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343584
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12000_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342738
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13154_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345768
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12079_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342813
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19044_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352639
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11835_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343578
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11995_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342733
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13155_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345769
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12077_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342811
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19046_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352641
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11834_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343577
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12020_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342758
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13156_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345770
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12075_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342809
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19049_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352644
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12765_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345385
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12016_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342754
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13162_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345776
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12067_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342801
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19045_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352640
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12763_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345383
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12015_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342753
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13163_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345777
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12060_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342794
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19047_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352642
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12762_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345382
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12013_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342751
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13118_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345734
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12054_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342788
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19048_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352643
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11962_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342700
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12007_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342745
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13110_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345726
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12053_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342787
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19050_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352645
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11959_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342697
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11998_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342736
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13116_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345732
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12033_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342771
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19059_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352654
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11846_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343589
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11996_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342734
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13149_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345763
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12032_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342770
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19061_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352656
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11845_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343588
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12023_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342761
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13150_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345764
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12030_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342768
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN19060_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43352655
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11843_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343586
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12021_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342759
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13151_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345765
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12029_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342767
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12176_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342910
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11840_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343583
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12010_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342748
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13161_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345775
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12109_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342843
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12175_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342909
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11839_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343582
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12006_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342744
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13166_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345780
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12108_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342842
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12204_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342938
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11837_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343580
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12005_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342743
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13108_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345724
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12102_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342836
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12174_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342908
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12764_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345384
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12004_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342742
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13104_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345720
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12100_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342834
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12167_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342901
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11828_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43343574
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12003_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342741
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13105_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345721
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12098_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342832
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12200_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342934
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11955_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342693
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11997_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342735
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13106_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345722
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12099_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342833
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12114_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342848
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11952_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342690
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12024_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342762
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13107_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345723
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12093_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342827
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12164_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342898
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11939_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342677
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12022_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342760
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13119_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345735
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12090_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342824
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12190_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342924
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11961_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342699
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12011_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342749
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13120_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345736
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12089_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342823
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12188_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342922
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN11964_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342702
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN12001_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43342739
# Error downloading https://nrs.harvard.edu/urn-3:HUAM:COIN13111_dlvr: 404 Client Error: Not Found for url: https://ids.lib.harvard.edu/ids/view/43345727
# Error saving file images\Byzantine\Paintings\urn-3:HUAM:INV126975_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Paintings\\urn-3:HUAM:INV126975_dynmc.jpg'
# Error saving file images\Byzantine\Paintings\urn-3:HUAM:VRS41328_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Paintings\\urn-3:HUAM:VRS41328_dynmc.jpg'
# Error saving file images\Byzantine\Paintings\urn-3:HUAM:VRS42664_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Paintings\\urn-3:HUAM:VRS42664_dynmc.jpg'
# Error saving file images\Byzantine\Paintings\urn-3:HUAM:VRS41546_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Paintings\\urn-3:HUAM:VRS41546_dynmc.jpg'
# Error saving file images\Byzantine\Paintings\urn-3:HUAM:VRS45496_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Paintings\\urn-3:HUAM:VRS45496_dynmc.jpg'
# Error saving file images\Byzantine\Paintings\urn-3:HUAM:VRS45497_dynmc.jpg: [Errno 22] Invalid argument: 'images\\Byzantine\\Paintings\\urn-3:HUAM:VRS45497_dynmc.jpg'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 98
#      96 # Download image and infer extension
#      97 try:
# ---> 98     r = requests.get(img_url, timeout=10)
#      99     r.raise_for_status()
#     100     ctype = r.headers.get('Content-Type', '')
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:652, in HTTPSConnection.connect(self)
#     649 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     650 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 652 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     653     sock=sock,
#     654     cert_reqs=self.cert_reqs,
#     655     ssl_version=self.ssl_version,
#     656     ssl_minimum_version=self.ssl_minimum_version,
#     657     ssl_maximum_version=self.ssl_maximum_version,
#     658     ca_certs=self.ca_certs,
#     659     ca_cert_dir=self.ca_cert_dir,
#     660     ca_cert_data=self.ca_cert_data,
#     661     cert_file=self.cert_file,
#     662     key_file=self.key_file,
#     663     key_password=self.key_password,
#     664     server_hostname=server_hostname_rm_dot,
#     665     ssl_context=self.ssl_context,
#     666     tls_in_tls=tls_in_tls,
#     667     assert_hostname=self.assert_hostname,
#     668     assert_fingerprint=self.assert_fingerprint,
#     669 )
#     670 self.sock = sock_and_verified.socket
#     672 # Forwarding proxies can never have a verified target since
#     673 # the proxy is the one doing the verification. Should instead
#     674 # use a CONNECT tunnel in order to verify the target.
#     675 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:805, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     802     if is_ipaddress(normalized):
#     803         server_hostname = normalized
# --> 805 ssl_sock = ssl_wrap_socket(
#     806     sock=sock,
#     807     keyfile=key_file,
#     808     certfile=cert_file,
#     809     key_password=key_password,
#     810     ca_certs=ca_certs,
#     811     ca_cert_dir=ca_cert_dir,
#     812     ca_cert_data=ca_cert_data,
#     813     server_hostname=server_hostname,
#     814     ssl_context=context,
#     815     tls_in_tls=tls_in_tls,
#     816 )
#     818 try:
#     819     if assert_fingerprint:
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     462 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     506     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File c:\Users\Kaiyan Zhang\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import os
import re
import csv
import requests
from urllib.parse import urlparse

# === Configuration ===
API_KEY = '8a3e7b04-96e1-45f3-9666-20c5dbb4dd88'  # replace with your Harvard Art Museums API key
BASE_URL = 'https://api.harvardartmuseums.org/object'
cultures = ["Byzantine", "Greek", "Roman", "Egyptian"]
classifications = [
    "Architecture Elements", "Coins", "Paintings", "Sculpture",
    "Seals", "Vessels", "Weapons and Ammunitions"
]
max_per_combo = 150
OUTPUT_CSV = 'metadata.csv'
IMAGE_ROOT = 'images'

# Initialize CSV
with open(OUTPUT_CSV, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['id','title','classification','century','culture','image_path'])

# Helpers
def sanitize(name):
    return re.sub(r'[<>:"/\\|?*]', '_', name)

def get_extension_from_url(url):
    path = urlparse(url).path
    ext = os.path.splitext(path)[1]
    return ext if ext and len(ext) <= 5 else '.jpg'

# Summary counters
total_downloaded = 0
breakdown = {}

# Main loop
for culture in cultures:
    for cls in classifications:
        print(f"Processing {culture} / {cls}...")
        # Fetch items
        items = []
        page = 1
        while True:
            params = {
                'apikey': API_KEY,
                'q': f'culture:"{culture}" AND classification:"{cls}"',
                'hasimage': 1,
                'size': 100,
                'page': page
            }
            resp = requests.get(BASE_URL, params=params)
            resp.raise_for_status()
            data = resp.json()
            recs = data.get('records', [])
            if not recs:
                break
            for rec in recs:
                if rec.get('primaryimageurl'):
                    items.append(rec)
                if len(items) >= max_per_combo * 2:
                    break
            if len(items) >= max_per_combo * 2 or not data.get('info', {}).get('next'):
                break
            page += 1

        # Select up to max_per_combo, balanced by century
        if len(items) > max_per_combo:
            by_century = {}
            for rec in items:
                cent = rec.get('century') or 'Unknown'
                by_century.setdefault(cent, []).append(rec)
            selected = []
            idxs = {c:0 for c in by_century}
            centuries = list(by_century.keys())
            i = 0
            while len(selected) < max_per_combo and centuries:
                cent = centuries[i % len(centuries)]
                lst = by_century[cent]
                if idxs[cent] < len(lst):
                    selected.append(lst[idxs[cent]])
                    idxs[cent] += 1
                else:
                    centuries.remove(cent)
                i += 1
            if len(selected) < max_per_combo:
                remaining = [r for r in items if r not in selected]
                selected += remaining[:max_per_combo - len(selected)]
        else:
            selected = items

        # Download images and write metadata
        count = 0
        for rec in selected:
            obj_id = rec.get('id')
            img_url = rec.get('primaryimageurl')
            title = rec.get('title','').replace('\n',' ').strip()
            century = rec.get('century','')
            if not img_url:
                continue
            # Determine extension
            ext = get_extension_from_url(img_url)
            # Filename
            safe_id = sanitize(str(obj_id))
            filename = f"{safe_id}{ext}"
            folder = os.path.join(IMAGE_ROOT, sanitize(culture), sanitize(cls))
            os.makedirs(folder, exist_ok=True)
            path = os.path.join(folder, filename)
            try:
                img_data = requests.get(img_url, timeout=15).content
                with open(path, 'wb') as f_img:
                    f_img.write(img_data)
            except Exception as e:
                print(f"Failed downloading {img_url}: {e}")
                continue
            # Append metadata
            with open(OUTPUT_CSV, 'a', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerow([obj_id, title, cls, century, culture, path])
            count += 1

        breakdown[(culture, cls)] = count
        total_downloaded += count
        print(f"Downloaded {count} images for {culture} / {cls}\n")

# Final summary
print(f"All done. Total images downloaded: {total_downloaded}")
print("Breakdown by culture and classification:")
for (culture, cls), cnt in breakdown.items():
    print(f" - {culture} / {cls}: {cnt}")
# Out:
# Processing Byzantine / Architecture Elements...
# Downloaded 1 images for Byzantine / Architecture Elements
#
# Processing Byzantine / Coins...
# Downloaded 150 images for Byzantine / Coins
#
# Processing Byzantine / Paintings...
# Downloaded 24 images for Byzantine / Paintings
#
# Processing Byzantine / Sculpture...
# Downloaded 36 images for Byzantine / Sculpture
#
# Processing Byzantine / Seals...
# Downloaded 150 images for Byzantine / Seals
#
# Processing Byzantine / Vessels...
# Downloaded 8 images for Byzantine / Vessels
#
# Processing Byzantine / Weapons and Ammunitions...
# Downloaded 0 images for Byzantine / Weapons and Ammunitions
#
# Processing Greek / Architecture Elements...
# Downloaded 9 images for Greek / Architecture Elements
#
# Processing Greek / Coins...
# Downloaded 150 images for Greek / Coins
#
# Processing Greek / Paintings...
# Downloaded 5 images for Greek / Paintings
#
# Processing Greek / Sculpture...
# Downloaded 150 images for Greek / Sculpture
#
# Processing Greek / Seals...
# Downloaded 6 images for Greek / Seals
#
# Processing Greek / Vessels...
# Downloaded 150 images for Greek / Vessels
#
# Processing Greek / Weapons and Ammunitions...
# Downloaded 12 images for Greek / Weapons and Ammunitions
#
# Processing Roman / Architecture Elements...
# Downloaded 21 images for Roman / Architecture Elements
#
# Processing Roman / Coins...
# Downloaded 150 images for Roman / Coins
#
# Processing Roman / Paintings...
# Downloaded 14 images for Roman / Paintings
#
# Processing Roman / Sculpture...
# Downloaded 150 images for Roman / Sculpture
#
# Processing Roman / Seals...
# Downloaded 6 images for Roman / Seals
#
# Processing Roman / Vessels...
# Downloaded 150 images for Roman / Vessels
#
# Processing Roman / Weapons and Ammunitions...
# Downloaded 3 images for Roman / Weapons and Ammunitions
#
# Processing Egyptian / Architecture Elements...
# Downloaded 1 images for Egyptian / Architecture Elements
#
# Processing Egyptian / Coins...
# Downloaded 1 images for Egyptian / Coins
#
# Processing Egyptian / Paintings...
# Downloaded 5 images for Egyptian / Paintings
#
# Processing Egyptian / Sculpture...
# Downloaded 150 images for Egyptian / Sculpture
#
# Processing Egyptian / Seals...
# Downloaded 4 images for Egyptian / Seals
#
# Processing Egyptian / Vessels...
# Downloaded 30 images for Egyptian / Vessels
#
# Processing Egyptian / Weapons and Ammunitions...
# Downloaded 1 images for Egyptian / Weapons and Ammunitions
#
# All done. Total images downloaded: 1537
# Breakdown by culture and classification:
#  - Byzantine / Architecture Elements: 1
#  - Byzantine / Coins: 150
#  - Byzantine / Paintings: 24
#  - Byzantine / Sculpture: 36
#  - Byzantine / Seals: 150
#  - Byzantine / Vessels: 8
#  - Byzantine / Weapons and Ammunitions: 0
#  - Greek / Architecture Elements: 9
#  - Greek / Coins: 150
#  - Greek / Paintings: 5
#  - Greek / Sculpture: 150
#  - Greek / Seals: 6
#  - Greek / Vessels: 150
#  - Greek / Weapons and Ammunitions: 12
#  - Roman / Architecture Elements: 21
#  - Roman / Coins: 150
#  - Roman / Paintings: 14
#  - Roman / Sculpture: 150
#  - Roman / Seals: 6
#  - Roman / Vessels: 150
#  - Roman / Weapons and Ammunitions: 3
#  - Egyptian / Architecture Elements: 1
#  - Egyptian / Coins: 1
#  - Egyptian / Paintings: 5
#  - Egyptian / Sculpture: 150
#  - Egyptian / Seals: 4
#  - Egyptian / Vessels: 30
#  - Egyptian / Weapons and Ammunitions: 1
